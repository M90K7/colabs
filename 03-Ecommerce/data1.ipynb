# %%
import pandas as pd
import numpy as np

# %%
pwd
# Out:
# '/content'

# %%
#https://www.kaggle.com/datasets/kaggle/sf-salaries

# %%
df=pd.read_csv('/content/drive/MyDrive/DB/Salaries.csv')
# Out:
# <ipython-input-3-fce344494d4a>:1: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('/content/drive/MyDrive/DB/Salaries.csv')

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# 3    77916.0    56120.71   198306.9      NaN  332343.61         332343.61
# 4   134401.6      9737.0  182234.59      NaN  326373.19         326373.19
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# ...

# %%
df.shape
# Out:
# (148654, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
df.describe()
# Out:
#                   Id       TotalPay  TotalPayBenefits           Year  Notes
# count  148654.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    74327.500000   74768.321972      93692.554811    2012.522643    NaN
# std     42912.857795   50517.005274      62793.533483       1.117538    NaN
# min         1.000000    -618.130000       -618.130000    2011.000000    NaN
# 25%     37164.250000   36168.995000      44065.650000    2012.000000    NaN
# 50%     74327.500000   71426.610000      92404.090000    2013.000000    NaN
# 75%    111490.750000  105839.135000     132876.450000    2014.000000    NaN
# max    148654.000000  567595.430000     567595.430000    2014.000000    NaN

# %%
df.drop('Notes',axis=1,inplace=True)

# %%
#df.drop('Status',axis=1,inplace=True)

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# 3    77916.0    56120.71   198306.9      NaN  332343.61         332343.61
# 4   134401.6      9737.0  182234.59      NaN  326373.19         326373.19
#
#    Year         Agency Status
# 0  2011  San Francisco    NaN
# ...

# %%
df['BasePay'].describe()
# Out:
# count     148049.0
# unique    109900.0
# top            0.0
# freq         875.0
# Name: BasePay, dtype: float64

# %%
df['BasePay'].describe().max()
# Out:
# 148049.0

# %%
df['TotalPay'].min()
# Out:
# -618.13

# %%
df['TotalPay'].idxmin()
# Out:
# 148653

# %%
df.iloc[148653]
# Out:
# Id                                      148654
# EmployeeName                         Joe Lopez
# JobTitle            Counselor, Log Cabin Ranch
# BasePay                                   0.00
# OvertimePay                               0.00
# OtherPay                               -618.13
# Benefits                                  0.00
# TotalPay                               -618.13
# TotalPayBenefits                       -618.13
# Year                                      2014
# Agency                           San Francisco
# Status                                      PT
# Name: 148653, dtype: object

# %%
df.iloc[df['TotalPay'].idxmin()]
# Out:
# Id                                      148654
# EmployeeName                         Joe Lopez
# JobTitle            Counselor, Log Cabin Ranch
# BasePay                                   0.00
# OvertimePay                               0.00
# OtherPay                               -618.13
# Benefits                                  0.00
# TotalPay                               -618.13
# TotalPayBenefits                       -618.13
# Year                                      2014
# Agency                           San Francisco
# Status                                      PT
# Name: 148653, dtype: object

# %%
df[df['TotalPay']==-618.13]  #conditional selection
# Out:
#             Id EmployeeName                    JobTitle BasePay OvertimePay  \
# 148653  148654    Joe Lopez  Counselor, Log Cabin Ranch    0.00        0.00
#
#        OtherPay Benefits  TotalPay  TotalPayBenefits  Year         Agency  \
# 148653  -618.13     0.00   -618.13           -618.13  2014  San Francisco
#
#        Status
# 148653     PT

# %%
#all negative totalpay

# %%
df[df['TotalPay']<0]
# Out:
#             Id EmployeeName                    JobTitle BasePay OvertimePay  \
# 148653  148654    Joe Lopez  Counselor, Log Cabin Ranch    0.00        0.00
#
#        OtherPay Benefits  TotalPay  TotalPayBenefits  Year         Agency  \
# 148653  -618.13     0.00   -618.13           -618.13  2014  San Francisco
#
#        Status
# 148653     PT

# %%
df['EmployeeName']=='Myisha Hervey'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 148649    False
# 148650    False
# 148651    False
# 148652    False
# 148653    False
# Name: EmployeeName, Length: 148654, dtype: bool

# %%
df[df['EmployeeName']=='Myisha Hervey']
# Out:
#           Id   EmployeeName              JobTitle   BasePay OvertimePay  \
# 53217  53218  Myisha Hervey  Management Assistant  73351.01         0.0
#
#       OtherPay  Benefits  TotalPay  TotalPayBenefits  Year         Agency  \
# 53217      0.0  32475.58  73351.01         105826.59  2012  San Francisco
#
#       Status
# 53217    NaN

# %%
#give name then get job title
df[df['EmployeeName']=='Myisha Hervey']['JobTitle']
# Out:
# 53217    Management Assistant
# Name: JobTitle, dtype: object

# %%
df[df['EmployeeName']=='Myisha Hervey']['TotalPay']
# Out:
# 53217    73351.01
# Name: TotalPay, dtype: float64

# %%
df['Year'].unique()
# Out:
# array([2011, 2012, 2013, 2014])

# %%
df['Year'].nunique()
# Out:
# 4

# %%
#number of jobtitles

# %%
df['JobTitle'].nunique()
# Out:
# 2159

# %%
a=df.groupby('Year').nunique()['JobTitle']
a
# Out:
# Year
# 2011    1045
# 2012    1044
# 2013    1051
# 2014     997
# Name: JobTitle, dtype: int64

# %%
a.iloc[0]
# Out:
# 1045

# %%
df['JobTitle'].value_counts()
# Out:
# JobTitle
# Transit Operator                                  7036
# Special Nurse                                     4389
# Registered Nurse                                  3736
# Public Svc Aide-Public Works                      2518
# Police Officer 3                                  2421
#                                                   ...
# CHIEF HOUSING INSPECTOR                              1
# TRAFFIC SIGNAL OPERATOR                              1
# COURT COMPUTER FACILITIES COORDINATOR                1
# AUTOMOTIVE BODY AND FENDER WORKER SUPERVISOR I       1
# VICTIM & WITNESS TECHNICIAN                          1
# Name: count, Length: 2159, dtype: int64

# %%
#top 5

# %%
df['JobTitle'].value_counts().head(5)
# Out:
# JobTitle
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: count, dtype: int64

# %%
df.groupby('Year').nunique()['JobTitle']
# Out:
# Year
# 2011    1045
# 2012    1044
# 2013    1051
# 2014     997
# Name: JobTitle, dtype: int64

# %%
#مجموع شغل  هایی که در2013 فقط برای یک نفر بوده است

# %%
sum(df[df['Year']==2013]['JobTitle'].value_counts()==1)
# Out:
# 202

# %%
df['JobTitle']
# Out:
# 0         GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                        CAPTAIN III (POLICE DEPARTMENT)
# 2                        CAPTAIN III (POLICE DEPARTMENT)
# 3                   WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4           DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#                                ...
# 148649                                         Custodian
# 148650                                      Not provided
# 148651                                      Not provided
# 148652                                      Not provided
# 148653                        Counselor, Log Cabin Ranch
# Name: JobTitle, Length: 148654, dtype: object

# %%
#افرادی که در تایتل شغلی از واژه
#cheif
#استفاده شده است

# %%
def chief_string(title):
    if 'chief' in title.lower():
        return True
    else:
        return False

# %%
chief_string('Custodian')
# Out:
# False

# %%
sum(df['JobTitle'].apply(lambda x: chief_string(x)))
# Out:
# 627

# %%
#ِDescribe  #predict
